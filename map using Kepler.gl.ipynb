# %%
import pandas as pd
import geopandas as gpd
from keplergl import KeplerGl

# %%
gdf = gpd.read_file('결과4326_2.shp', encoding='euc-kr')
#gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf['xcoord'], gdf['ycoord']))

# %%
gdf.info()

# %%
#Create a basemap 
map = KeplerGl(height=600, width=800)
#show the map
map

# %%
# Add data to Kepler
map.add_data(data=gdf, name= "bldg01")

# %%
map.save_to_html(file_name="map.html", )
